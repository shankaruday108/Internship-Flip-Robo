# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.8.0-py3-none-any.whl (6.3 MB)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\shank\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\shank\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\shank\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\users\shank\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in c:\users\shank\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: sortedcontainers in c:\users\shank\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\shank\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: pycparser in c:\users\shank\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\shank\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, exceptiongroup, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed async-generator-1.10 exceptiongroup-1.1.0 h11-0.14.0 outcome-1.2.0 selenium-4.8.0 trio-0.22.0 trio-websocket-0.9.2 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import selenium as sm
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# Now we have to download the webdriver of the same version which is in our chrome version otherwise it will not work

# %%
# Now connection to the driver which is available in this folder of my laptop
driver = webdriver.Chrome(r"D:\Uday Shankar's Data\Softwares\chromedriver_win32\chromedriver.exe")

# %%
# Now opening the naukri.com website in a new window
driver.get("https://www.naukri.com/")

# %%
designation_first = driver.find_element(By.CLASS_NAME, "suggestor-input ")
designation_first.send_keys("Python")

# %%
location = driver.find_element(By.XPATH, "/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys("Delhi")

# %%
search = driver.find_element(By.CLASS_NAME, "qsbSubmit")
search.click()

# %%
start = 
job_titles = []
job_locations = []
company_name = []
experience_required = []

# %%
title = driver.find_elements(By.XPATH, "//a[@class='title ellipsis']")
end = len(title)

for i in title[start:end]:
    job_titles.append(i.text)
    
job_titles
# Out:
# ['Senior Python Developer',
#  'Python/Java/Golang -Developer',
#  'Tech Mahindra is Hiring For Python Developer',
#  'Python Software Developer',
#  'Python Developer - Django/Data Structure',
#  'Python Software Developer',
#  'Sr Python Developer',
#  'Python Software Developer',
#  'Python Software Developer',
#  'Tcs is Hiring Python Developers For PAN India',
#  'Python Developers',
#  'Sr. Data Analyst (Python/SQL/Analytics)',
#  'Python/Data Science Developer',
#  'Senior Full Stack Developer - Python / JavaScript',
#  'Senior Python Developer',
#  'Data Engineer- Python',
#  'Python Developer',
#  'Python Developer / Machine Learning Engineer',
#  'Big Data Developer - Scala/ Python',
#  'Full Stack Developer - SQL/Python/Javascript']

# %%
location = driver.find_elements(By.XPATH, "//span[@class='ellipsis fleft locWdth']")
end = len(location)

for i in location[start:end]:
    job_locations.append(i.text)
    
job_locations
# Out:
# ['Noida, Bangalore/Bengaluru',
#  'Gurgaon/Gurugram',
#  'Hybrid - Noida',
#  'Noida(Sector-125 Noida)',
#  'Noida, Gurgaon/Gurugram, Greater Noida, Punjab, Delhi NCR',
#  'Noida, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'Noida, Gurgaon/Gurugram',
#  'Gurgaon/Gurugram, Bangalore/Bengaluru',
#  'Delhi / NCR, Kolkata, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Delhi / NCR, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Noida, Chennai, Bangalore/Bengaluru',
#  'Temp. WFH - Delhi / NCR, Hyderabad/Secunderabad, Bangalore/Bengaluru',
#  'Delhi / NCR, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru',
#  'Hybrid - Noida, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'Hybrid - Delhi / NCR, Gurgaon/Gurugram',
#  'Permanent Remote',
#  'Gurgaon/Gurugram',
#  'Delhi / NCR, Gurgaon/Gurugram',
#  'Delhi / NCR, Gurgaon/Gurugram']

# %%
company = driver.find_elements(By.XPATH, "//a[@class='subTitle ellipsis fleft']")
end = len(company)

for i in company[start:end]:
    company_name.append(i.text)
    
company_name
# Out:
# ['Genpact',
#  'Ciena',
#  'Tech Mahindra',
#  'Corbus',
#  'Appscrip',
#  'HCLTech',
#  'Megma Services',
#  'Advance Career Solutions',
#  'Screatives Software Services',
#  'Tata Consultancy Services (TCS)',
#  'HCLTech',
#  'Groundtruth',
#  'TRH Consultancy Services',
#  'Datatobiz',
#  'HCLTech',
#  'Gigmo Solutions',
#  'Megma Services',
#  'Huquo Consulting Pvt. Ltd',
#  'Huquo Consulting',
#  'Huquo Consulting Pvt. Ltd']

# %%
experience = driver.find_elements(By.XPATH, "//span[@class='ellipsis fleft expwdth']")
end = len(experience)

for i in experience[start:end]:
    experience_required.append(i.text)
    
experience_required
# Out:
# ['7-12 Yrs',
#  '2-3 Yrs',
#  '3-8 Yrs',
#  '4-8 Yrs',
#  '0-1 Yrs',
#  '4-7 Yrs',
#  '3-8 Yrs',
#  '9-12 Yrs',
#  '7-9 Yrs',
#  '2-6 Yrs',
#  '5-10 Yrs',
#  '4-7 Yrs',
#  '5-10 Yrs',
#  '5-10 Yrs',
#  '5-9 Yrs',
#  '3-8 Yrs',
#  '1-4 Yrs',
#  '2-7 Yrs',
#  '2-7 Yrs',
#  '4-9 Yrs']

# %%
all_data = pd.DataFrame({'Job Title':job_titles, 'Job Location':job_locations, 'Company Name':company_name, 'Experience Required':experience_required})
all_data
# Out:
#                                             Job Title  \
# 0                             Senior Python Developer
# 1                       Python/Java/Golang -Developer
# 2        Tech Mahindra is Hiring For Python Developer
# 3                           Python Software Developer
# 4            Python Developer - Django/Data Structure
# 5                           Python Software Developer
# 6                                 Sr Python Developer
# 7                           Python Software Developer
# 8                           Python Software Developer
# 9       Tcs is Hiring Python Developers For PAN India
# 10                                  Python Developers
# 11            Sr. Data Analyst (Python/SQL/Analytics)
# 12                      Python/Data Science Developer
# 13  Senior Full Stack Developer - Python / JavaScript
# 14                            Senior Python Developer
# 15                              Data Engineer- Python
# 16                                   Python Developer
# 17       Python Developer / Machine Learning Engineer
# 18                 Big Data Developer - Scala/ Python
# 19       Full Stack Developer - SQL/Python/Javascript
#
#                                          Job Location  \
# 0                          Noida, Bangalore/Bengaluru
# 1                                    Gurgaon/Gurugram
# 2                                      Hybrid - Noida
# 3                             Noida(Sector-125 Noida)
# 4   Noida, Gurgaon/Gurugram, Greater Noida, Punjab...
# 5   Noida, Hyderabad/Secunderabad, Pune, Chennai, ...
# 6                             Noida, Gurgaon/Gurugram
# 7               Gurgaon/Gurugram, Bangalore/Bengaluru
# 8   Delhi / NCR, Kolkata, Hyderabad/Secunderabad, ...
# 9   Delhi / NCR, Bangalore/Bengaluru, Mumbai (All ...
# 10                Noida, Chennai, Bangalore/Bengaluru
# 11  Temp. WFH - Delhi / NCR, Hyderabad/Secunderaba...
# 12  Delhi / NCR, Mumbai, Hyderabad/Secunderabad, P...
# 13  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 14  Hybrid - Noida, Hyderabad/Secunderabad, Pune, ...
# 15             Hybrid - Delhi / NCR, Gurgaon/Gurugram
# 16                                   Permanent Remote
# 17                                   Gurgaon/Gurugram
# 18                      Delhi / NCR, Gurgaon/Gurugram
# 19                      Delhi / NCR, Gurgaon/Gurugram
#
#                        Company Name Experience Required
# 0                           Genpact            7-12 Yrs
# 1                             Ciena             2-3 Yrs
# 2                     Tech Mahindra             3-8 Yrs
# 3                            Corbus             4-8 Yrs
# 4                          Appscrip             0-1 Yrs
# 5                           HCLTech             4-7 Yrs
# 6                    Megma Services             3-8 Yrs
# 7          Advance Career Solutions            9-12 Yrs
# 8      Screatives Software Services             7-9 Yrs
# 9   Tata Consultancy Services (TCS)             2-6 Yrs
# 10                          HCLTech            5-10 Yrs
# 11                      Groundtruth             4-7 Yrs
# 12         TRH Consultancy Services            5-10 Yrs
# 13                        Datatobiz            5-10 Yrs
# 14                          HCLTech             5-9 Yrs
# 15                  Gigmo Solutions             3-8 Yrs
# 16                   Megma Services             1-4 Yrs
# 17        Huquo Consulting Pvt. Ltd             2-7 Yrs
# 18                 Huquo Consulting             2-7 Yrs
# 19        Huquo Consulting Pvt. Ltd             4-9 Yrs

# %%
all_data.to_csv("selenium_naukri_dot_com_data.csv", header=True, index=False)
