# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup as bs
import requests as rq
import pandas as pd

# %%
page = rq.get('https://www.dineout.co.in/delhi-restaurants')

# %%
page
# Out:
# <Response [200]>

# %%
soup = bs(page.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><link href="/manifest.json" rel="manifest"/><style type="text/css">
#             @font-face {
#                 font-family: 'dineicon';
#                 src:  url('/fonts/dineicon.eot');
#                 src:  url('/fonts/dineicon.eot#iefix') format('embedded-opentype'),
#                 url('/fonts/dineicon.ttf') format('truetype'),
#                 url('/fonts/dineicon.woff') format('woff'),
#                 url('/fonts/dineicon.svg#dineicon') format('svg');
#                 font-weight: normal;
# 				font-style: normal;
# 				font-display: swap;
#             }
#             .hide {
#                 display: none !important;
#             }
#             .async-hide{
#                 opacity: inherit !important;
#             }
# ...

# %%
first_title = soup.find("a",class_="restnt-name ellipsis") # This is for get single data
first_title
# Out:
# <a analytics-action="RestaurantCardClick" analytics-label="20996_Tamasha" class="restnt-name ellipsis" data-w-onclick="sendAnalyticsCommon|w1-restarant" href="/delhi/tamasha-connaught-place-central-delhi-20996">Tamasha</a>

# %%
title = first_title.text 
title
# Out:
# 'Tamasha'

# %%
titles = []

for title in soup.find_all("a",class_="restnt-name ellipsis"):
    titles.append(title.text)
    
titles
# Out:
# ['TamashaTamashaTamashaTamasha',
#  'LocalLocalLocalLocal',
#  'Ministry Of BeerMinistry Of BeerMinistry Of BeerMinistry Of Beer',
#  'Station BarStation BarStation BarStation Bar',
#  'Unplugged CourtyardUnplugged CourtyardUnplugged CourtyardUnplugged Courtyard',
#  'My Bar SquareMy Bar SquareMy Bar SquareMy Bar Square',
#  'Cafe High 5Cafe High 5Cafe High 5Cafe High 5',
#  'Openhouse CafeOpenhouse CafeOpenhouse CafeOpenhouse Cafe',
#  'The Junkyard CafeThe Junkyard CafeThe Junkyard CafeThe Junkyard Cafe',
#  'Warehouse CafeWarehouse CafeWarehouse CafeWarehouse Cafe',
#  'The G.T. RoadThe G.T. RoadThe G.T. RoadThe G.T. Road',
#  'Lord of the DrinksLord of the DrinksLord of the DrinksLord of the Drinks',
#  'DasaprakashDasaprakashDasaprakashDasaprakash',
#  'QBAQBAQBAQBA',
#  'Out Of The Box CourtyardOut Of The Box CourtyardOut Of The Box CourtyardOut Of The Box Courtyard',
#  'Somewhere Restaurant & BarSomewhere Restaurant & BarSomewhere Restaurant & BarSomewhere Restaurant & Bar',
# ...

# %%
locations = []

for location in soup.find_all("div",class_="restnt-loc ellipsis"):
    locations.append(location.text)
    
locations
# Out:
# ['Connaught Place, Central Delhi',
#  'Scindia House,Connaught Place, Central Delhi',
#  'M-Block,Connaught Place, Central Delhi',
#  'F-Block,Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'M-Block,Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'M-Block,Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi']

# %%
prices = []

for price in soup.find_all("span",class_="double-line-ellipsis"):
    prices.append(price.text.split('|')[0])
    
prices
# Out:
# ['₹ 2,000 for 2 (approx) ',
#  '₹ 2,000 for 2 (approx) ',
#  '₹ 3,000 for 2 (approx) ',
#  '₹ 1,100 for 2 (approx) ',
#  '₹ 3,300 for 2 (approx) ',
#  '₹ 2,000 for 2 (approx) ',
#  '₹ 1,700 for 2 (approx) ',
#  '₹ 2,000 for 2 (approx) ',
#  '₹ 2,100 for 2 (approx) ',
#  '₹ 2,500 for 2 (approx) ',
#  '₹ 2,000 for 2 (approx) ',
#  '₹ 2,500 for 2 (approx) ',
#  '₹ 800 for 2 (approx) ',
#  '₹ 2,100 for 2 (approx) ',
#  '₹ 2,200 for 2 (approx) ',
#  '₹ 1,000 for 2 (approx) ',
#  '₹ 1,800 for 2 (approx) ',
#  '₹ 2,700 for 2 (approx) ',
#  '₹ 2,000 for 2 (approx) ',
#  '₹ 1,400 for 2 (approx) ',
#  '₹ 1,800 for 2 (approx) ']

# %%
images = []

for img in soup.find_all("img",class_="no-img"):
    images.append(img.get('data-src'))
    
images
# Out:
# ['https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/a/j/p20996-145631488756cd9a0796608.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/b/t/p27452-15020105505986dcb6d147f.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/a/d/p32381-1495943585592a49a166fe7.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/9/i/b/p971-165909823762e3d47db6d56.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/u/y/p20941-15700828565d959028e9f28.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/m/i/p12709-15681189525d7798a8c5aa5.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/6/d/f/p69146-16614287776307642999f0a.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/j/y/p19748-16474299906231c96621c58.jpg?tr=tr:n-medium',
# ...

# %%
all_data = pd.DataFrame({'Title':titles, 'Location':locations, 'Price':prices, 'Image':images})
all_data
# Out:
#                                                 Title  \
# 0                        TamashaTamashaTamashaTamasha
# 1                                LocalLocalLocalLocal
# 2   Ministry Of BeerMinistry Of BeerMinistry Of Be...
# 3        Station BarStation BarStation BarStation Bar
# 4   Unplugged CourtyardUnplugged CourtyardUnplugge...
# 5   My Bar SquareMy Bar SquareMy Bar SquareMy Bar ...
# 6        Cafe High 5Cafe High 5Cafe High 5Cafe High 5
# 7   Openhouse CafeOpenhouse CafeOpenhouse CafeOpen...
# 8   The Junkyard CafeThe Junkyard CafeThe Junkyard...
# 9   Warehouse CafeWarehouse CafeWarehouse CafeWare...
# 10  The G.T. RoadThe G.T. RoadThe G.T. RoadThe G.T...
# 11  Lord of the DrinksLord of the DrinksLord of th...
# 12       DasaprakashDasaprakashDasaprakashDasaprakash
# 13                                       QBAQBAQBAQBA
# 14  Out Of The Box CourtyardOut Of The Box Courtya...
# 15  Somewhere Restaurant & BarSomewhere Restaurant...
# ...

# %%
# saving the dataframe
all_data.to_csv('beautiful_soup.csv', header=True, index=False)
